# %%
import gzip            
import io              
import numpy as np
import pandas as pd    
import pymysql.cursors 
import rdflib
from rdflib import Namespace
import urllib.request 
import math

import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %matplotlib inline

# Connect to the database

connection = pymysql.connect(host='hosting.nyu.edu',
                             user='cmrougha_adsq',
                             password='###REPLACE###',
                             db='cmrougha_adsq2017',
                             charset='utf8mb4',
                             cursorclass=pymysql.cursors.DictCursor)

# %% [markdown]
# # RDF and Queries
#
# Search for the header 'Some Queries' to skip to the queries run on the resultant RDF graph.
#
# Initial work experimented with converting a number of different tables from the SQL database into RDF, but this notebook focuses on one table newly created this week, `17.3.9_pinAstr_all`. This table combines all information drawn from Pinakes with new, randomly generated identifiers (columns starting with `astrID_`) for each author, work, witness of that work, and manuscript. This allows for easier work with the hundreds of non-Little Astronomy texts that have been included in the database (formerly only Little Astronomy texts and authors had received unique identifiers).
#
# This table, `17.3.9_pinAstr_all`, is not at all in any normal forms, but the notebook uses various SQL queries to pull out columns with distinct values that are then input into the RDF graph.
#
# The full table has 2,871 columns and 26 rows. A sample of the table is below:

# %%
sql = """
SELECT * FROM `17.3.9_pinAstr_all`
 """
with connection.cursor() as cursor:
    cursor.execute(sql)
    names = [ x[0] for x in cursor.description]
    result = cursor.fetchall()
df = pd.DataFrame(result, columns = names)

df.head()
# Out:
#        witness astrID_wi     MS astrID_ms            Pays      Ville  \
# 0   6769_11734   4512229  11734     26250    Magyarország   Budapest
# 1   1484_11734   4739938  11734     26250    Magyarország   Budapest
# 2    913_11734   9876248  11734     26250    Magyarország   Budapest
# 3    969_11734   6792546  11734     26250    Magyarország   Budapest
# 4  12764_11895   3068424  11895     34044  United Kingdom  Cambridge
#
#                          Depot            Fonds                    Cote  \
# 0  Országos Széchényi Könyvtár  fonds principal  4° Gr. 01 (Kubinyi 10)
# 1  Országos Széchényi Könyvtár  fonds principal  4° Gr. 01 (Kubinyi 10)
# 2  Országos Széchényi Könyvtár  fonds principal  4° Gr. 01 (Kubinyi 10)
# 3  Országos Széchényi Könyvtár  fonds principal  4° Gr. 01 (Kubinyi 10)
# 4        Queen's College Libr.  fonds principal                      19
#
#                   Folios      ...       Identifiant Recension BHG DateLit.  \
# 0                002-30*      ...
# 1               030-53v*      ...
# 2               066v-69v      ...
# 3  074v-140 , p. 280-288      ...
# 4                001-233      ...
#
#   Siècle Date Commentaire Contenu Rev. Bibliographies
# 0     16
# 1     16
# 2     16
# 3     16
# 4     16         Libb 1-9
#
# [5 rows x 26 columns]

# %% [markdown]
# ## A Function to convert to RDF

# %%
def convertToRDF(g,df,primaryKey):
    pseudo_triples = pd.melt(df,id_vars=primaryKey)
    for t in pseudo_triples.iterrows():
        for resourceKey in resourceSyntax:
            if primaryKey in resourceSyntax[resourceKey]:
                s = rdflib.URIRef(resourceKey + t[1][primaryKey])
    
        for verbKey in verbs:
            if t[1]['variable'] in verbs[verbKey]:
                p = rdflib.URIRef(verbKey)
            
        g.add((s,rdflib.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),rdflib.URIRef('http://www.w3.org/2004/02/skos/core#Concept')))

        if t[1]['value'] == None or t[1]['value'] == '':
            print(t)
        elif isinstance(t[1]['value'], float) and math.isnan(t[1]['value']):
            print(t)
        else:
            if t[1]['variable'] in literals:
                if t[1]['variable'] in languages:
                    o = rdflib.Literal(t[1]['value'],lang=languages[t[1]['variable']])
                else:
                    o = rdflib.Literal(t[1]['value'])
                g.add((s,p,o))
            
            elif t[1]['variable'] in numerics:
                o = rdflib.Literal(int(t[1]['value']))
                g.add((s,p,o))
    
            elif t[1]['variable'] in resources:
                for resourceKey in resourceSyntax:
                    if t[1]['variable'] in resourceSyntax[resourceKey]:
                        o = rdflib.URIRef(resourceKey + str(t[1]['value']))
                        g.add((s,p,o))
        
            else:
                print('Error: Unknown whether %s is a literal or resource.' % t[1]['variable'])
    return g

# %% [markdown]
# # RDF Conversion
#
# ## Geographic Information
#
# ### MS to Institution

# %%
sql = """
SELECT DISTINCT astrID_ms, REPLACE(REPLACE(REPLACE(REPLACE(REPLACE(REPLACE(Depot,')',''),'(',''),"'",""),'.',''),',',''),' ','') AS institution
 FROM `17.3.9_pinAstr_all`
 """
with connection.cursor() as cursor:
    cursor.execute(sql)
    names = [ x[0] for x in cursor.description]
    result = cursor.fetchall()
df = pd.DataFrame(result, columns = names)

df.head()
# Out:
#   astrID_ms                institution
# 0     26250  OrszágosSzéchényiKönyvtár
# 1     34044          QueensCollegeLibr
# 2     65283             TrinityCollege
# 3     48846             TrinityCollege
# 4     34813          UniversityLibrary

# %%
# astrID_ms, Depot from `17.3.9_pinAstr_all`

literals = list()

resources = list()
resources.append('astrID_ms')
resources.append('institution')

numerics = list()

verbs = dict()
verbs['http://www.w3.org/2004/02/skos/core#prefLabel'] = list()

verbs['http://example.org/vocab/locatedIn'] = list()
verbs['http://example.org/vocab/locatedIn'].append('institution')

resourceSyntax = dict()
resourceSyntax['http://example.org/id/'] = list()
resourceSyntax['http://example.org/id/'].append('astrID_ms')
resourceSyntax['http://example.org/id/'].append('institution')

# %%
g = rdflib.Graph()

# %%
primaryKey = 'astrID_ms'

g = convertToRDF(g,df,primaryKey)

# %%
result = g.query(
        """SELECT * WHERE {
            ?1s ?2p ?3o .
                }""")

pd.DataFrame(result.bindings).head()
# Out:
#                             1s  \
# 0  http://example.org/id/35515
# 1  http://example.org/id/49015
# 2  http://example.org/id/10018
# 3  http://example.org/id/86643
# 4  http://example.org/id/85473
#
#                                                 2p  \
# 0               http://example.org/vocab/locatedIn
# 1               http://example.org/vocab/locatedIn
# 2  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 3  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 4               http://example.org/vocab/locatedIn
#
#                                                   3o
# 0              http://example.org/id/BodleianLibrary
# 1  http://example.org/id/BibliothèquenationaledeF...
# 2        http://www.w3.org/2004/02/skos/core#Concept
# 3        http://www.w3.org/2004/02/skos/core#Concept
# 4              http://example.org/id/BodleianLibrary

# %% [markdown]
# ### Institution to Pinakes Label

# %%
sql = """
SELECT DISTINCT Depot, REPLACE(REPLACE(REPLACE(REPLACE(REPLACE(REPLACE(Depot,')',''),'(',''),"'",""),'.',''),',',''),' ','') AS institution
 FROM `17.3.9_pinAstr_all`
 """
with connection.cursor() as cursor:
    cursor.execute(sql)
    names = [ x[0] for x in cursor.description]
    result = cursor.fetchall()
df = pd.DataFrame(result, columns = names)

df.head()
# Out:
#                                  Depot                     institution
# 0          Országos Széchényi Könyvtár       OrszágosSzéchényiKönyvtár
# 1                Queen's College Libr.               QueensCollegeLibr
# 2                      Trinity College                  TrinityCollege
# 3                   University Library               UniversityLibrary
# 4  Thirlestaine House, coll. Phillipps  ThirlestaineHousecollPhillipps

# %%
# Depot from `17.3.9_pinAstr_all`

literals.append('Depot')

verbs['http://www.w3.org/2004/02/skos/core#prefLabel'].append('Depot')

languages = dict()

# %%
primaryKey = 'institution'

g = convertToRDF(g,df,primaryKey)

# %%
result = g.query(
        """SELECT * WHERE {
            ?1s ?2p ?3o .
                }""")

pd.DataFrame(result.bindings).head()
# Out:
#                                                   1s  \
# 0                        http://example.org/id/35515
# 1                        http://example.org/id/49015
# 2                        http://example.org/id/10018
# 3  http://example.org/id/BibliotecaMediceaLaurenz...
# 4                        http://example.org/id/86643
#
#                                                 2p  \
# 0               http://example.org/vocab/locatedIn
# 1               http://example.org/vocab/locatedIn
# 2  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 3  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 4  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
#
#                                                   3o
# 0              http://example.org/id/BodleianLibrary
# 1  http://example.org/id/BibliothèquenationaledeF...
# 2        http://www.w3.org/2004/02/skos/core#Concept
# 3        http://www.w3.org/2004/02/skos/core#Concept
# 4        http://www.w3.org/2004/02/skos/core#Concept

# %% [markdown]
# ### Institution to City

# %%
sql = """
SELECT DISTINCT REPLACE(REPLACE(REPLACE(REPLACE(REPLACE(REPLACE(Ville,')',''),'(',''),"'",""),'.',''),',',''),' ','') AS city, REPLACE(REPLACE(REPLACE(REPLACE(REPLACE(REPLACE(Depot,')',''),'(',''),"'",""),'.',''),',',''),' ','') AS institution
 FROM `17.3.9_pinAstr_all`
 """
with connection.cursor() as cursor:
    cursor.execute(sql)
    names = [ x[0] for x in cursor.description]
    result = cursor.fetchall()
df = pd.DataFrame(result, columns = names)

df.head()
# Out:
#          city                     institution
# 0    Budapest       OrszágosSzéchényiKönyvtár
# 1   Cambridge               QueensCollegeLibr
# 2   Cambridge                  TrinityCollege
# 3   Cambridge               UniversityLibrary
# 4  Cheltenham  ThirlestaineHousecollPhillipps

# %%
# Depot, Ville from `17.3.9_pinAstr_all`

resources.append('city')

verbs['http://example.org/vocab/locatedIn'].append('city')

resourceSyntax['http://example.org/id/'].append('city')

# %%
primaryKey = 'institution'

g = convertToRDF(g,df,primaryKey)

# %%
result = g.query(
        """SELECT * WHERE {
            ?1s ?2p ?3o .
                }""")

pd.DataFrame(result.bindings).head()
# Out:
#                                                   1s  \
# 0                        http://example.org/id/35515
# 1                        http://example.org/id/49015
# 2                        http://example.org/id/10018
# 3  http://example.org/id/BibliotecaMediceaLaurenz...
# 4                        http://example.org/id/86643
#
#                                                 2p  \
# 0               http://example.org/vocab/locatedIn
# 1               http://example.org/vocab/locatedIn
# 2  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 3  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 4  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
#
#                                                   3o
# 0              http://example.org/id/BodleianLibrary
# 1  http://example.org/id/BibliothèquenationaledeF...
# 2        http://www.w3.org/2004/02/skos/core#Concept
# 3        http://www.w3.org/2004/02/skos/core#Concept
# 4        http://www.w3.org/2004/02/skos/core#Concept

# %% [markdown]
# ### City to Pinakes Label

# %%
sql = """
SELECT DISTINCT Ville, REPLACE(REPLACE(REPLACE(REPLACE(REPLACE(REPLACE(Ville,')',''),'(',''),"'",""),'.',''),',',''),' ','') AS city
 FROM `17.3.9_pinAstr_all`
 """
with connection.cursor() as cursor:
    cursor.execute(sql)
    names = [ x[0] for x in cursor.description]
    result = cursor.fetchall()
df = pd.DataFrame(result, columns = names)

df.head()
# Out:
#               Ville           city
# 0          Budapest       Budapest
# 1         Cambridge      Cambridge
# 2        Cheltenham     Cheltenham
# 3      Chicago (IL)      ChicagoIL
# 4  Cologny (Genève)  ColognyGenève

# %%
# Ville from `17.3.9_pinAstr_all`

literals.append('Ville')

verbs['http://www.w3.org/2004/02/skos/core#prefLabel'].append('Ville')

languages = dict()

# %%
primaryKey = 'city'

g = convertToRDF(g,df,primaryKey)

# %%
result = g.query(
        """SELECT * WHERE {
            ?1s ?2p ?3o .
                }""")

pd.DataFrame(result.bindings).head()
# Out:
#                                                   1s  \
# 0  http://example.org/id/BibliotecaMediceaLaurenz...
# 1                        http://example.org/id/27520
# 2              http://example.org/id/NewberryLibrary
# 3                        http://example.org/id/36188
# 4                        http://example.org/id/36188
#
#                                                 2p  \
# 0  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 1               http://example.org/vocab/locatedIn
# 2    http://www.w3.org/2004/02/skos/core#prefLabel
# 3  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 4               http://example.org/vocab/locatedIn
#
#                                                   3o
# 0        http://www.w3.org/2004/02/skos/core#Concept
# 1  http://example.org/id/BibliotecaApostolicaVati...
# 2                                   Newberry Library
# 3        http://www.w3.org/2004/02/skos/core#Concept
# 4        http://example.org/id/BibliotecaCasanatense

# %% [markdown]
# ### City to Country

# %%
sql = """
SELECT DISTINCT REPLACE(REPLACE(REPLACE(REPLACE(REPLACE(REPLACE(Ville,')',''),'(',''),"'",""),'.',''),',',''),' ','') AS city, REPLACE(REPLACE(REPLACE(REPLACE(REPLACE(REPLACE(Pays,')',''),'(',''),"'",""),'.',''),',',''),' ','') AS country
 FROM `17.3.9_pinAstr_all`
 """
with connection.cursor() as cursor:
    cursor.execute(sql)
    names = [ x[0] for x in cursor.description]
    result = cursor.fetchall()
df = pd.DataFrame(result, columns = names)

df.head()
# Out:
#             city                country
# 0       Budapest           Magyarország
# 1      Cambridge          UnitedKingdom
# 2     Cheltenham          UnitedKingdom
# 3      ChicagoIL  UnitedStatesofAmerica
# 4  ColognyGenève                 Suisse

# %%
# Pays, Ville from `17.3.9_pinAstr_all`

resources.append('country')

verbs['http://example.org/vocab/locatedIn'].append('country')

resourceSyntax['http://example.org/id/'].append('country')

# %%
primaryKey = 'city'

g = convertToRDF(g,df,primaryKey)

# %%
result = g.query(
        """SELECT * WHERE {
            ?1s ?2p ?3o .
                }""")

pd.DataFrame(result.bindings).head()
# Out:
#                                                   1s  \
# 0  http://example.org/id/BibliotecaMediceaLaurenz...
# 1                        http://example.org/id/27520
# 2              http://example.org/id/NewberryLibrary
# 3                        http://example.org/id/36188
# 4                        http://example.org/id/36188
#
#                                                 2p  \
# 0  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 1               http://example.org/vocab/locatedIn
# 2    http://www.w3.org/2004/02/skos/core#prefLabel
# 3  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 4               http://example.org/vocab/locatedIn
#
#                                                   3o
# 0        http://www.w3.org/2004/02/skos/core#Concept
# 1  http://example.org/id/BibliotecaApostolicaVati...
# 2                                   Newberry Library
# 3        http://www.w3.org/2004/02/skos/core#Concept
# 4        http://example.org/id/BibliotecaCasanatense

# %% [markdown]
# ### Country to Pinakes Label

# %%
sql = """
SELECT DISTINCT Pays, REPLACE(REPLACE(REPLACE(REPLACE(REPLACE(REPLACE(Pays,')',''),'(',''),"'",""),'.',''),',',''),' ','') AS country
 FROM `17.3.9_pinAstr_all`
 """
with connection.cursor() as cursor:
    cursor.execute(sql)
    names = [ x[0] for x in cursor.description]
    result = cursor.fetchall()
df = pd.DataFrame(result, columns = names)

df.head()
# Out:
#                        Pays                country
# 0              Magyarország           Magyarország
# 1            United Kingdom          UnitedKingdom
# 2  United States of America  UnitedStatesofAmerica
# 3                    Suisse                 Suisse
# 4                    Hellas                 Hellas

# %%
# Ville from `17.3.9_pinAstr_all`

literals.append('Pays')

verbs['http://www.w3.org/2004/02/skos/core#prefLabel'].append('Pays')

# %%
primaryKey = 'country'

g = convertToRDF(g,df,primaryKey)

# %%
result = g.query(
        """SELECT * WHERE {
            ?1s <http://www.w3.org/2004/02/skos/core#prefLabel> ?3o .
                }""")

pd.DataFrame(result.bindings).head()
# Out:
#                                                   1s  \
# 0  http://example.org/id/StaatsbibliothekzuBerlin...
# 1                     http://example.org/id/Budapest
# 2                   http://example.org/id/Cheltenham
# 3  http://example.org/id/ÖsterreichischeNationalb...
# 4                      http://example.org/id/Belluno
#
#                                                   3o
# 0  Staatsbibliothek zu Berlin (Preussischer Kultu...
# 1                                           Budapest
# 2                                         Cheltenham
# 3           Österreichische Nationalbibliothek (ÖNB)
# 4                                            Belluno

# %% [markdown]
# ## The Manuscripts

# %% [markdown]
# ### Astr to Pinakes ID and Label
#
# * Perhaps adjust SQL query to give not Pinakes 'ID' but Pinakes URLs instead.

# %%
sql = """
SELECT DISTINCT astrID_ms, MS, CONCAT(Fonds, ' ', Cote) AS shelfmark
 FROM `17.3.9_pinAstr_all`
 """
with connection.cursor() as cursor:
    cursor.execute(sql)
    names = [ x[0] for x in cursor.description]
    result = cursor.fetchall()
df = pd.DataFrame(result, columns = names)

df.head()
# Out:
#   astrID_ms     MS                               shelfmark
# 0     26250  11734  fonds principal 4° Gr. 01 (Kubinyi 10)
# 1     34044  11895                      fonds principal 19
# 2     65283  12000          fonds principal O.05.15 (1296)
# 3     48846  12028          fonds principal O.10.12 (1464)
# 4     34813  12151          Fonds ancien Dd. III. 86 (173)

# %%
# MS, astrID_ms, Fonds, Cote from `17.3.9_pinAstr_all`

literals.append('MS')
literals.append('shelfmark')

verbs['http://example.org/vocab/pinakesLabel'] = list()
verbs['http://example.org/vocab/pinakesLabel'].append('shelfmark')

verbs['http://example.org/vocab/pinakesID'] = list()
verbs['http://example.org/vocab/pinakesID'].append('MS')

# %%
primaryKey = 'astrID_ms'

g = convertToRDF(g,df,primaryKey)

# %%
result = g.query(
        """SELECT * WHERE {
            ?1s ?2p ?3o .
                }""")

pd.DataFrame(result.bindings).head()
# Out:
#                                                   1s  \
# 0                        http://example.org/id/38962
# 1                        http://example.org/id/37642
# 2  http://example.org/id/BibliotecaMediceaLaurenz...
# 3                        http://example.org/id/10384
# 4                        http://example.org/id/27520
#
#                                                 2p  \
# 0               http://example.org/vocab/pinakesID
# 1               http://example.org/vocab/pinakesID
# 2  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 3            http://example.org/vocab/pinakesLabel
# 4               http://example.org/vocab/locatedIn
#
#                                                   3o
# 0                                              52908
# 1                                              53639
# 2        http://www.w3.org/2004/02/skos/core#Concept
# 3                           fonds principal III C 16
# 4  http://example.org/id/BibliotecaApostolicaVati...

# %% [markdown]
# ### Manuscript to Witness

# %%
sql = """
SELECT DISTINCT astrID_ms, astrID_wi
 FROM `17.3.9_pinAstr_all`
 """
with connection.cursor() as cursor:
    cursor.execute(sql)
    names = [ x[0] for x in cursor.description]
    result = cursor.fetchall()
df = pd.DataFrame(result, columns = names)

df.head()
# Out:
#   astrID_ms astrID_wi
# 0     26250   4512229
# 1     26250   4739938
# 2     26250   9876248
# 3     26250   6792546
# 4     34044   3068424

# %%
# astrID_ms, astrID_wi from `17.3.9_pinAstr_all`

resources.append('astrID_wi')

verbs['http://example.org/vocab/msContains'] = list()
verbs['http://example.org/vocab/msContains'].append('astrID_wi')

resourceSyntax['http://example.org/id/'].append('astrID_wi')

# %%
primaryKey = 'astrID_ms'

g = convertToRDF(g,df,primaryKey)

# %%
result = g.query(
        """SELECT * WHERE {
            ?1s ?2p ?3o .
                }""")

pd.DataFrame(result.bindings).head()
# Out:
#                             1s                                     2p  \
# 0  http://example.org/id/10384  http://example.org/vocab/pinakesLabel
# 1  http://example.org/id/74476    http://example.org/vocab/msContains
# 2  http://example.org/id/24255    http://example.org/vocab/msContains
# 3  http://example.org/id/27520     http://example.org/vocab/locatedIn
# 4  http://example.org/id/50249    http://example.org/vocab/msContains
#
#                                                   3o
# 0                           fonds principal III C 16
# 1                      http://example.org/id/6937052
# 2                      http://example.org/id/6474501
# 3  http://example.org/id/BibliotecaApostolicaVati...
# 4                      http://example.org/id/6367870

# %%
# REVERSE
# astrID_ms, astrID_wi from `17.3.9_pinAstr_all`

verbs['http://example.org/vocab/inMS'] = list()
verbs['http://example.org/vocab/inMS'].append('astrID_ms')

# %%
primaryKey = 'astrID_wi'

g = convertToRDF(g,df,primaryKey)

# %%
result = g.query(
        """SELECT * WHERE {
            ?1s ?2p ?3o .
                }""")

pd.DataFrame(result.bindings).head()
# Out:
#                               1s  \
# 0  http://example.org/id/1593312
# 1    http://example.org/id/10384
# 2    http://example.org/id/74476
# 3  http://example.org/id/3283681
# 4  http://example.org/id/5490346
#
#                                                 2p  \
# 0  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 1            http://example.org/vocab/pinakesLabel
# 2              http://example.org/vocab/msContains
# 3  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 4  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
#
#                                             3o
# 0  http://www.w3.org/2004/02/skos/core#Concept
# 1                     fonds principal III C 16
# 2                http://example.org/id/6937052
# 3  http://www.w3.org/2004/02/skos/core#Concept
# 4  http://www.w3.org/2004/02/skos/core#Concept

# %% [markdown]
# ### Witness to Pinakes ID, Folios, and Century
#
# * note: witness is not a real Pinakes ID but was constructed from MS and Work. maybe remove later.

# %%
sql = """
SELECT DISTINCT astrID_wi, witness, Folios, `Siècle`
 FROM `17.3.9_pinAstr_all`
 """
with connection.cursor() as cursor:
    cursor.execute(sql)
    names = [ x[0] for x in cursor.description]
    result = cursor.fetchall()
df = pd.DataFrame(result, columns = names)

df.head()
# Out:
#   astrID_wi      witness                 Folios Siècle
# 0   4512229   6769_11734                002-30*     16
# 1   4739938   1484_11734               030-53v*     16
# 2   9876248    913_11734               066v-69v     16
# 3   6792546    969_11734  074v-140 , p. 280-288     16
# 4   3068424  12764_11895                001-233     16

# %%
# MS, astrID_ms, Fonds, Cote from `17.3.9_pinAstr_all`

literals.append('witness')
literals.append('Folios')
literals.append('Siècle')

verbs['http://example.org/vocab/pinakesID'].append('witness')

verbs['http://example.org/vocab/pinakesFolios'] = list()
verbs['http://example.org/vocab/pinakesFolios'].append('Folios')

verbs['http://example.org/vocab/pinakesCentury'] = list()
verbs['http://example.org/vocab/pinakesCentury'].append('Siècle')

# %%
primaryKey = 'astrID_wi'

g = convertToRDF(g,df,primaryKey)
# Out:
# (2865, astrID_wi    5190893
# variable      Folios
# value
# Name: 2865, dtype: object)
# (2879, astrID_wi    6217728
# variable      Folios
# value
# Name: 2879, dtype: object)
# (2880, astrID_wi    2157240
# variable      Folios
# value
# Name: 2880, dtype: object)
# (2881, astrID_wi    6008159
# variable      Folios
# value
# Name: 2881, dtype: object)
# (2905, astrID_wi    8453548
# variable      Folios
# value
# Name: 2905, dtype: object)
# (2906, astrID_wi    5699821
# variable      Folios
# value
# Name: 2906, dtype: object)
# (2907, astrID_wi    9861742
# variable      Folios
# value
# Name: 2907, dtype: object)
# (2908, astrID_wi    9174426
# variable      Folios
# value
# Name: 2908, dtype: object)
# (2909, astrID_wi    1737086
# variable      Folios
# value
# Name: 2909, dtype: object)
# (2910, astrID_wi    2553686
# variable      Folios
# value
# Name: 2910, dtype: object)
# (2911, astrID_wi    3215662
# variable      Folios
# value
# Name: 2911, dtype: object)
# (2923, astrID_wi    5854917
# variable      Folios
# value
# Name: 2923, dtype: object)
# (2924, astrID_wi    7816388
# variable      Folios
# value
# Name: 2924, dtype: object)
# (2925, astrID_wi    4441161
# variable      Folios
# value
# Name: 2925, dtype: object)
# (2926, astrID_wi    8123795
# variable      Folios
# value
# Name: 2926, dtype: object)
# (2927, astrID_wi    9394779
# variable      Folios
# value
# Name: 2927, dtype: object)
# (2928, astrID_wi    8678906
# variable      Folios
# value
# Name: 2928, dtype: object)
# (2929, astrID_wi    9703894
# variable      Folios
# value
# Name: 2929, dtype: object)
# (2930, astrID_wi    9703894
# variable      Folios
# value
# Name: 2930, dtype: object)
# (2931, astrID_wi    6999912
# variable      Folios
# value
# Name: 2931, dtype: object)
# (2932, astrID_wi    4516238
# variable      Folios
# value
# Name: 2932, dtype: object)
# (2933, astrID_wi    3029356
# variable      Folios
# value
# Name: 2933, dtype: object)
# (2934, astrID_wi    7074184
# variable      Folios
# value
# Name: 2934, dtype: object)
# (2935, astrID_wi    2184618
# variable      Folios
# value
# Name: 2935, dtype: object)
# (2936, astrID_wi    7430912
# variable      Folios
# value
# Name: 2936, dtype: object)
# (2937, astrID_wi    1189259
# variable      Folios
# value
# Name: 2937, dtype: object)
# (2938, astrID_wi    5682904
# variable      Folios
# value
# Name: 2938, dtype: object)
# (2939, astrID_wi    2823129
# variable      Folios
# value
# Name: 2939, dtype: object)
# (2940, astrID_wi    3552971
# variable      Folios
# value
# Name: 2940, dtype: object)
# (2941, astrID_wi    1392928
# variable      Folios
# value
# Name: 2941, dtype: object)
# (2942, astrID_wi    4449847
# variable      Folios
# value
# Name: 2942, dtype: object)
# (2943, astrID_wi    1920624
# variable      Folios
# value
# Name: 2943, dtype: object)
# (2944, astrID_wi    3794528
# variable      Folios
# value
# Name: 2944, dtype: object)
# (2945, astrID_wi    2942273
# variable      Folios
# value
# Name: 2945, dtype: object)
# (2946, astrID_wi    5248456
# variable      Folios
# value
# Name: 2946, dtype: object)
# (2947, astrID_wi    5092758
# variable      Folios
# value
# Name: 2947, dtype: object)
# (2948, astrID_wi    7803387
# variable      Folios
# value
# Name: 2948, dtype: object)
# (2949, astrID_wi    8544575
# variable      Folios
# value
# Name: 2949, dtype: object)
# (2950, astrID_wi    9272564
# variable      Folios
# value
# Name: 2950, dtype: object)
# (2951, astrID_wi    8047169
# variable      Folios
# value
# Name: 2951, dtype: object)
# (2952, astrID_wi    7297653
# variable      Folios
# value
# Name: 2952, dtype: object)
# (2953, astrID_wi    9532486
# variable      Folios
# value
# Name: 2953, dtype: object)
# (2954, astrID_wi    2007028
# variable      Folios
# value
# Name: 2954, dtype: object)
# (2955, astrID_wi    2356620
# variable      Folios
# value
# Name: 2955, dtype: object)
# (2956, astrID_wi    9600179
# variable      Folios
# value
# Name: 2956, dtype: object)
# (2957, astrID_wi    3785520
# variable      Folios
# value
# Name: 2957, dtype: object)
# (3004, astrID_wi    9668583
# variable      Folios
# value
# Name: 3004, dtype: object)
# (3005, astrID_wi    8441821
# variable      Folios
# value
# Name: 3005, dtype: object)
# (3006, astrID_wi    2634856
# variable      Folios
# value
# Name: 3006, dtype: object)
# (3007, astrID_wi    6703952
# variable      Folios
# value
# Name: 3007, dtype: object)
# (3008, astrID_wi    1008055
# variable      Folios
# value
# Name: 3008, dtype: object)
# (3009, astrID_wi    4736670
# variable      Folios
# value
# Name: 3009, dtype: object)
# (3010, astrID_wi    8358259
# variable      Folios
# value
# Name: 3010, dtype: object)
# (3011, astrID_wi    9033638
# variable      Folios
# value
# Name: 3011, dtype: object)
# (3252, astrID_wi    9773056
# variable      Folios
# value
# Name: 3252, dtype: object)
# (3260, astrID_wi    3140313
# variable      Folios
# value
# Name: 3260, dtype: object)
# (3264, astrID_wi    8265082
# variable      Folios
# value
# Name: 3264, dtype: object)
# (3265, astrID_wi    7308880
# variable      Folios
# value
# Name: 3265, dtype: object)
# (3266, astrID_wi    2808950
# variable      Folios
# value
# Name: 3266, dtype: object)
# (3267, astrID_wi    2808950
# variable      Folios
# value
# Name: 3267, dtype: object)
# (3268, astrID_wi    3014612
# variable      Folios
# value
# Name: 3268, dtype: object)
# (3269, astrID_wi    3312898
# variable      Folios
# value
# Name: 3269, dtype: object)
# (3438, astrID_wi    9215788
# variable      Folios
# value
# Name: 3438, dtype: object)
# (3440, astrID_wi    8547064
# variable      Folios
# value
# Name: 3440, dtype: object)
# (3441, astrID_wi    4247968
# variable      Folios
# value
# Name: 3441, dtype: object)
# (3442, astrID_wi    4247968
# variable      Folios
# value
# Name: 3442, dtype: object)
# (3443, astrID_wi    7994722
# variable      Folios
# value
# Name: 3443, dtype: object)
# (3444, astrID_wi    8814566
# variable      Folios
# value
# Name: 3444, dtype: object)
# (3448, astrID_wi    5281132
# variable      Folios
# value
# Name: 3448, dtype: object)
# (3452, astrID_wi    3785853
# variable      Folios
# value
# Name: 3452, dtype: object)
# (3453, astrID_wi    8852388
# variable      Folios
# value
# Name: 3453, dtype: object)
# (3455, astrID_wi    4806094
# variable      Folios
# value
# Name: 3455, dtype: object)
# (3456, astrID_wi    8976561
# variable      Folios
# value
# Name: 3456, dtype: object)
# (3457, astrID_wi    4570229
# variable      Folios
# value
# Name: 3457, dtype: object)
# (3458, astrID_wi    8257235
# variable      Folios
# value
# Name: 3458, dtype: object)
# (3459, astrID_wi    8859061
# variable      Folios
# value
# Name: 3459, dtype: object)
# (3460, astrID_wi    6303685
# variable      Folios
# value
# Name: 3460, dtype: object)
# (3461, astrID_wi    1138680
# variable      Folios
# value
# Name: 3461, dtype: object)
# (3462, astrID_wi    5420074
# variable      Folios
# value
# Name: 3462, dtype: object)
# (3463, astrID_wi    3698437
# variable      Folios
# value
# Name: 3463, dtype: object)
# (3464, astrID_wi    6210660
# variable      Folios
# value
# Name: 3464, dtype: object)
# (3496, astrID_wi    5685940
# variable      Folios
# value
# Name: 3496, dtype: object)
# (3497, astrID_wi    5351653
# variable      Folios
# value
# Name: 3497, dtype: object)
# (3516, astrID_wi    2013539
# variable      Folios
# value
# Name: 3516, dtype: object)
# (3629, astrID_wi    3530888
# variable      Folios
# value
# Name: 3629, dtype: object)
# (3630, astrID_wi    7217535
# variable      Folios
# value
# Name: 3630, dtype: object)
# (3829, astrID_wi    7393868
# variable      Folios
# value
# Name: 3829, dtype: object)
# (3830, astrID_wi    5767986
# variable      Folios
# value
# Name: 3830, dtype: object)
# (3831, astrID_wi    9152165
# variable      Folios
# value
# Name: 3831, dtype: object)
# (3840, astrID_wi    1113586
# variable      Folios
# value
# Name: 3840, dtype: object)
# (3841, astrID_wi    1672269
# variable      Folios
# value
# Name: 3841, dtype: object)
# (3842, astrID_wi    2643371
# variable      Folios
# value
# Name: 3842, dtype: object)
# (3843, astrID_wi    2628410
# variable      Folios
# value
# Name: 3843, dtype: object)
# (3844, astrID_wi    8088207
# variable      Folios
# value
# Name: 3844, dtype: object)
# (3845, astrID_wi    8255450
# variable      Folios
# value
# Name: 3845, dtype: object)
# (3846, astrID_wi    3696187
# variable      Folios
# value
# Name: 3846, dtype: object)
# (3847, astrID_wi    3878508
# variable      Folios
# value
# Name: 3847, dtype: object)
# (3989, astrID_wi    4238445
# variable      Folios
# value
# Name: 3989, dtype: object)
# (4024, astrID_wi    3413674
# variable      Folios
# value
# Name: 4024, dtype: object)
# (4039, astrID_wi    5900183
# variable      Folios
# value
# Name: 4039, dtype: object)
# (4055, astrID_wi    2736193
# variable      Folios
# value
# Name: 4055, dtype: object)
# (4216, astrID_wi    5541184
# variable      Folios
# value
# Name: 4216, dtype: object)
# (4233, astrID_wi    1264601
# variable      Folios
# value
# Name: 4233, dtype: object)
# (4234, astrID_wi    5596709
# variable      Folios
# value
# Name: 4234, dtype: object)
# (4308, astrID_wi    4418417
# variable      Folios
# value
# Name: 4308, dtype: object)
# (4314, astrID_wi    1371470
# variable      Folios
# value
# Name: 4314, dtype: object)
# (4668, astrID_wi    4516880
# variable      Folios
# value
# Name: 4668, dtype: object)
# (4670, astrID_wi    2649168
# variable      Folios
# value
# Name: 4670, dtype: object)
# (4671, astrID_wi    6055176
# variable      Folios
# value
# Name: 4671, dtype: object)
# (4672, astrID_wi    1138549
# variable      Folios
# value
# Name: 4672, dtype: object)
# (4673, astrID_wi    2130889
# variable      Folios
# value
# Name: 4673, dtype: object)
# (4674, astrID_wi    4505083
# variable      Folios
# value
# Name: 4674, dtype: object)
# (4699, astrID_wi    2414804
# variable      Folios
# value
# Name: 4699, dtype: object)
# (4714, astrID_wi    4820236
# variable      Folios
# value
# Name: 4714, dtype: object)
# (4715, astrID_wi    6724859
# variable      Folios
# value
# Name: 4715, dtype: object)
# (4716, astrID_wi    3542858
# variable      Folios
# value
# Name: 4716, dtype: object)
# (4717, astrID_wi    1819388
# variable      Folios
# value
# Name: 4717, dtype: object)
# (4718, astrID_wi    5682689
# variable      Folios
# value
# Name: 4718, dtype: object)
# (4719, astrID_wi    3755944
# variable      Folios
# value
# Name: 4719, dtype: object)
# (4720, astrID_wi    3838496
# variable      Folios
# value
# Name: 4720, dtype: object)
# (4721, astrID_wi    6640981
# variable      Folios
# value
# Name: 4721, dtype: object)
# (4722, astrID_wi    2212311
# variable      Folios
# value
# Name: 4722, dtype: object)
# (4723, astrID_wi    6928683
# variable      Folios
# value
# Name: 4723, dtype: object)
# (4737, astrID_wi    2005697
# variable      Folios
# value
# Name: 4737, dtype: object)
# (4738, astrID_wi    8823125
# variable      Folios
# value
# Name: 4738, dtype: object)
# (4739, astrID_wi    1869352
# variable      Folios
# value
# Name: 4739, dtype: object)
# (4830, astrID_wi    7982288
# variable      Folios
# value
# Name: 4830, dtype: object)
# (4831, astrID_wi    2761713
# variable      Folios
# value
# Name: 4831, dtype: object)
# (4888, astrID_wi    6077237
# variable      Folios
# value
# Name: 4888, dtype: object)
# (4945, astrID_wi    9891958
# variable      Folios
# value
# Name: 4945, dtype: object)
# (5208, astrID_wi    3926754
# variable      Folios
# value
# Name: 5208, dtype: object)
# (5209, astrID_wi    8020751
# variable      Folios
# value
# Name: 5209, dtype: object)
# (5210, astrID_wi    9690334
# variable      Folios
# value
# Name: 5210, dtype: object)
# (5211, astrID_wi    5246664
# variable      Folios
# value
# Name: 5211, dtype: object)
# (5212, astrID_wi    4940209
# variable      Folios
# value
# Name: 5212, dtype: object)
# (5213, astrID_wi    5003576
# variable      Folios
# value
# Name: 5213, dtype: object)
# (5214, astrID_wi    6519388
# variable      Folios
# value
# Name: 5214, dtype: object)
# (5215, astrID_wi    1555295
# variable      Folios
# value
# Name: 5215, dtype: object)
# (5216, astrID_wi    2700849
# variable      Folios
# value
# Name: 5216, dtype: object)
# (5217, astrID_wi    7153800
# variable      Folios
# value
# Name: 5217, dtype: object)
# (5239, astrID_wi    7472961
# variable      Folios
# value
# Name: 5239, dtype: object)
# (5299, astrID_wi    7239571
# variable      Folios
# value
# Name: 5299, dtype: object)
# (5608, astrID_wi    8975031
# variable      Folios
# value
# Name: 5608, dtype: object)
# (5641, astrID_wi    4253272
# variable      Folios
# value
# Name: 5641, dtype: object)
# (5642, astrID_wi    4380288
# variable      Folios
# value
# Name: 5642, dtype: object)
# (5643, astrID_wi    5993464
# variable      Folios
# value
# Name: 5643, dtype: object)
# (5644, astrID_wi    5546212
# variable      Folios
# value
# Name: 5644, dtype: object)
# (5645, astrID_wi    5857477
# variable      Folios
# value
# Name: 5645, dtype: object)
# (5646, astrID_wi    1850847
# variable      Folios
# value
# Name: 5646, dtype: object)
# (5648, astrID_wi    7776294
# variable      Folios
# value
# Name: 5648, dtype: object)
# (5649, astrID_wi    3393991
# variable      Folios
# value
# Name: 5649, dtype: object)
# (5693, astrID_wi    2754311
# variable      Folios
# value
# Name: 5693, dtype: object)
# (5708, astrID_wi    9275358
# variable      Folios
# value
# Name: 5708, dtype: object)
# (5729, astrID_wi    9460137
# variable      Siècle
# value
# Name: 5729, dtype: object)
# (5739, astrID_wi    6217728
# variable      Siècle
# value
# Name: 5739, dtype: object)
# (5740, astrID_wi    2157240
# variable      Siècle
# value
# Name: 5740, dtype: object)
# (5741, astrID_wi    6008159
# variable      Siècle
# value
# Name: 5741, dtype: object)
# (5765, astrID_wi    8453548
# variable      Siècle
# value
# Name: 5765, dtype: object)
# (5766, astrID_wi    5699821
# variable      Siècle
# value
# Name: 5766, dtype: object)
# (5783, astrID_wi    5854917
# variable      Siècle
# value
# Name: 5783, dtype: object)
# (5784, astrID_wi    7816388
# variable      Siècle
# value
# Name: 5784, dtype: object)
# (5785, astrID_wi    4441161
# variable      Siècle
# value
# Name: 5785, dtype: object)
# (5786, astrID_wi    8123795
# variable      Siècle
# value
# Name: 5786, dtype: object)
# (5787, astrID_wi    9394779
# variable      Siècle
# value
# Name: 5787, dtype: object)
# (5789, astrID_wi    9703894
# variable      Siècle
# value
# Name: 5789, dtype: object)
# (5793, astrID_wi    3029356
# variable      Siècle
# value
# Name: 5793, dtype: object)
# (5794, astrID_wi    7074184
# variable      Siècle
# value
# Name: 5794, dtype: object)
# (5796, astrID_wi    7430912
# variable      Siècle
# value
# Name: 5796, dtype: object)
# (5797, astrID_wi    1189259
# variable      Siècle
# value
# Name: 5797, dtype: object)
# (5799, astrID_wi    2823129
# variable      Siècle
# value
# Name: 5799, dtype: object)
# (5800, astrID_wi    3552971
# variable      Siècle
# value
# Name: 5800, dtype: object)
# (5801, astrID_wi    1392928
# variable      Siècle
# value
# Name: 5801, dtype: object)
# (5802, astrID_wi    4449847
# variable      Siècle
# value
# Name: 5802, dtype: object)
# (5803, astrID_wi    1920624
# variable      Siècle
# value
# Name: 5803, dtype: object)
# (5804, astrID_wi    3794528
# variable      Siècle
# value
# Name: 5804, dtype: object)
# (5805, astrID_wi    2942273
# variable      Siècle
# value
# Name: 5805, dtype: object)
# (5806, astrID_wi    5248456
# variable      Siècle
# value
# Name: 5806, dtype: object)
# (5807, astrID_wi    5092758
# variable      Siècle
# value
# Name: 5807, dtype: object)
# (5808, astrID_wi    7803387
# variable      Siècle
# value
# Name: 5808, dtype: object)
# (5811, astrID_wi    8047169
# variable      Siècle
# value
# Name: 5811, dtype: object)
# (5812, astrID_wi    7297653
# variable      Siècle
# value
# Name: 5812, dtype: object)
# (5813, astrID_wi    9532486
# variable      Siècle
# value
# Name: 5813, dtype: object)
# (5815, astrID_wi    2356620
# variable      Siècle
# value
# Name: 5815, dtype: object)
# (5816, astrID_wi    9600179
# variable      Siècle
# value
# Name: 5816, dtype: object)
# (5817, astrID_wi    3785520
# variable      Siècle
# value
# Name: 5817, dtype: object)
# (5818, astrID_wi    6479559
# variable      Siècle
# value
# Name: 5818, dtype: object)
# (5819, astrID_wi    9799626
# variable      Siècle
# value
# Name: 5819, dtype: object)
# (5820, astrID_wi    2381569
# variable      Siècle
# value
# Name: 5820, dtype: object)
# (5821, astrID_wi    1979454
# variable      Siècle
# value
# Name: 5821, dtype: object)
# (5822, astrID_wi    8293992
# variable      Siècle
# value
# Name: 5822, dtype: object)
# (5823, astrID_wi    5748366
# variable      Siècle
# value
# Name: 5823, dtype: object)
# (5824, astrID_wi    3256640
# variable      Siècle
# value
# Name: 5824, dtype: object)
# (5825, astrID_wi    6251400
# variable      Siècle
# value
# Name: 5825, dtype: object)
# (5826, astrID_wi    4595369
# variable      Siècle
# value
# Name: 5826, dtype: object)
# (5827, astrID_wi    2099546
# variable      Siècle
# value
# Name: 5827, dtype: object)
# (5828, astrID_wi    2630504
# variable      Siècle
# value
# Name: 5828, dtype: object)
# (5829, astrID_wi    2071830
# variable      Siècle
# value
# Name: 5829, dtype: object)
# (5830, astrID_wi    1735546
# variable      Siècle
# value
# Name: 5830, dtype: object)
# (5831, astrID_wi    6920963
# variable      Siècle
# value
# Name: 5831, dtype: object)
# (5832, astrID_wi    4583788
# variable      Siècle
# value
# Name: 5832, dtype: object)
# (5833, astrID_wi    3528578
# variable      Siècle
# value
# Name: 5833, dtype: object)
# (5834, astrID_wi    1041600
# variable      Siècle
# value
# Name: 5834, dtype: object)
# (5835, astrID_wi    4692922
# variable      Siècle
# value
# Name: 5835, dtype: object)
# (5836, astrID_wi    1803002
# variable      Siècle
# value
# Name: 5836, dtype: object)
# (5837, astrID_wi    9198804
# variable      Siècle
# value
# Name: 5837, dtype: object)
# (5838, astrID_wi    7065220
# variable      Siècle
# value
# Name: 5838, dtype: object)
# (5839, astrID_wi    1181756
# variable      Siècle
# value
# Name: 5839, dtype: object)
# (5840, astrID_wi    7807354
# variable      Siècle
# value
# Name: 5840, dtype: object)
# (5841, astrID_wi    8114340
# variable      Siècle
# value
# Name: 5841, dtype: object)
# (5842, astrID_wi    3265864
# variable      Siècle
# value
# Name: 5842, dtype: object)
# (5843, astrID_wi    7897949
# variable      Siècle
# value
# Name: 5843, dtype: object)
# (5844, astrID_wi    7807354
# variable      Siècle
# value
# Name: 5844, dtype: object)
# (5845, astrID_wi    7816344
# variable      Siècle
# value
# Name: 5845, dtype: object)
# (5846, astrID_wi    1248448
# variable      Siècle
# value
# Name: 5846, dtype: object)
# (5847, astrID_wi    4500257
# variable      Siècle
# value
# Name: 5847, dtype: object)
# (5848, astrID_wi    2227186
# variable      Siècle
# value
# Name: 5848, dtype: object)
# (5849, astrID_wi    5642733
# variable      Siècle
# value
# Name: 5849, dtype: object)
# (5850, astrID_wi    1643070
# variable      Siècle
# value
# Name: 5850, dtype: object)
# (5851, astrID_wi    7688983
# variable      Siècle
# value
# Name: 5851, dtype: object)
# (5852, astrID_wi    4917535
# variable      Siècle
# value
# Name: 5852, dtype: object)
# (5853, astrID_wi    9870295
# variable      Siècle
# value
# Name: 5853, dtype: object)
# (5854, astrID_wi    7816344
# variable      Siècle
# value
# Name: 5854, dtype: object)
# (5855, astrID_wi    4919780
# variable      Siècle
# value
# Name: 5855, dtype: object)
# (5856, astrID_wi    6189090
# variable      Siècle
# value
# Name: 5856, dtype: object)
# (5857, astrID_wi    4446793
# variable      Siècle
# value
# Name: 5857, dtype: object)
# (5858, astrID_wi    3455009
# variable      Siècle
# value
# Name: 5858, dtype: object)
# (5859, astrID_wi    2706519
# variable      Siècle
# value
# Name: 5859, dtype: object)
# (5860, astrID_wi    8302382
# variable      Siècle
# value
# Name: 5860, dtype: object)
# (5861, astrID_wi    1153067
# variable      Siècle
# value
# Name: 5861, dtype: object)
# (5862, astrID_wi    4635628
# variable      Siècle
# value
# Name: 5862, dtype: object)
# (5863, astrID_wi    1231098
# variable      Siècle
# value
# Name: 5863, dtype: object)
# (5864, astrID_wi    9668583
# variable      Siècle
# value
# Name: 5864, dtype: object)
# (5865, astrID_wi    8441821
# variable      Siècle
# value
# Name: 5865, dtype: object)
# (5866, astrID_wi    2634856
# variable      Siècle
# value
# Name: 5866, dtype: object)
# (5867, astrID_wi    6703952
# variable      Siècle
# value
# Name: 5867, dtype: object)
# (5868, astrID_wi    1008055
# variable      Siècle
# value
# Name: 5868, dtype: object)
# (5869, astrID_wi    4736670
# variable      Siècle
# value
# Name: 5869, dtype: object)
# (5870, astrID_wi    8358259
# variable      Siècle
# value
# Name: 5870, dtype: object)
# (5871, astrID_wi    9033638
# variable      Siècle
# value
# Name: 5871, dtype: object)
# (5872, astrID_wi    6657410
# variable      Siècle
# value
# Name: 5872, dtype: object)
# (5873, astrID_wi    5911934
# variable      Siècle
# value
# Name: 5873, dtype: object)
# (5874, astrID_wi    1661008
# variable      Siècle
# value
# Name: 5874, dtype: object)
# (5875, astrID_wi    9850615
# variable      Siècle
# value
# Name: 5875, dtype: object)
# (5878, astrID_wi    1363540
# variable      Siècle
# value
# Name: 5878, dtype: object)
# (5916, astrID_wi    1991454
# variable      Siècle
# value
# Name: 5916, dtype: object)
# (5924, astrID_wi    6755207
# variable      Siècle
# value
# Name: 5924, dtype: object)
# (5988, astrID_wi    2038434
# variable      Siècle
# value
# Name: 5988, dtype: object)
# (6082, astrID_wi    3598355
# variable      Siècle
# value
# Name: 6082, dtype: object)
# (6125, astrID_wi    7308880
# variable      Siècle
# value
# Name: 6125, dtype: object)
# (6127, astrID_wi    2808950
# variable      Siècle
# value
# Name: 6127, dtype: object)
# (6170, astrID_wi    3989133
# variable      Siècle
# value
# Name: 6170, dtype: object)
# (6209, astrID_wi    5361587
# variable      Siècle
# value
# Name: 6209, dtype: object)
# (6212, astrID_wi    7292543
# variable      Siècle
# value
# Name: 6212, dtype: object)
# (6298, astrID_wi    9215788
# variable      Siècle
# value
# Name: 6298, dtype: object)
# (6300, astrID_wi    8547064
# variable      Siècle
# value
# Name: 6300, dtype: object)
# (6301, astrID_wi    4247968
# variable      Siècle
# value
# Name: 6301, dtype: object)
# (6304, astrID_wi    8814566
# variable      Siècle
# value
# Name: 6304, dtype: object)
# (6308, astrID_wi    5281132
# variable      Siècle
# value
# Name: 6308, dtype: object)
# (6312, astrID_wi    3785853
# variable      Siècle
# value
# Name: 6312, dtype: object)
# (6313, astrID_wi    8852388
# variable      Siècle
# value
# Name: 6313, dtype: object)
# (6315, astrID_wi    4806094
# variable      Siècle
# value
# Name: 6315, dtype: object)
# (6316, astrID_wi    8976561
# variable      Siècle
# value
# Name: 6316, dtype: object)
# (6317, astrID_wi    4570229
# variable      Siècle
# value
# Name: 6317, dtype: object)
# (6318, astrID_wi    8257235
# variable      Siècle
# value
# Name: 6318, dtype: object)
# (6319, astrID_wi    8859061
# variable      Siècle
# value
# Name: 6319, dtype: object)
# (6320, astrID_wi    6303685
# variable      Siècle
# value
# Name: 6320, dtype: object)
# (6321, astrID_wi    1138680
# variable      Siècle
# value
# Name: 6321, dtype: object)
# (6322, astrID_wi    5420074
# variable      Siècle
# value
# Name: 6322, dtype: object)
# (6323, astrID_wi    3698437
# variable      Siècle
# value
# Name: 6323, dtype: object)
# (6324, astrID_wi    6210660
# variable      Siècle
# value
# Name: 6324, dtype: object)
# (6333, astrID_wi    8976561
# variable      Siècle
# value
# Name: 6333, dtype: object)
# (6361, astrID_wi    6987977
# variable      Siècle
# value
# Name: 6361, dtype: object)
# (6372, astrID_wi    1593312
# variable      Siècle
# value
# Name: 6372, dtype: object)
# (6507, astrID_wi    5203222
# variable      Siècle
# value
# Name: 6507, dtype: object)
# (6509, astrID_wi    8362252
# variable      Siècle
# value
# Name: 6509, dtype: object)
# (6534, astrID_wi    6243916
# variable      Siècle
# value
# Name: 6534, dtype: object)
# (6538, astrID_wi    6310842
# variable      Siècle
# value
# Name: 6538, dtype: object)
# (6547, astrID_wi    4675628
# variable      Siècle
# value
# Name: 6547, dtype: object)
# (6551, astrID_wi    5164601
# variable      Siècle
# value
# Name: 6551, dtype: object)
# (6553, astrID_wi    3604342
# variable      Siècle
# value
# Name: 6553, dtype: object)
# (6557, astrID_wi    9199162
# variable      Siècle
# value
# Name: 6557, dtype: object)
# (6558, astrID_wi    9199162
# variable      Siècle
# value
# Name: 6558, dtype: object)
# (6593, astrID_wi    6128843
# variable      Siècle
# value
# Name: 6593, dtype: object)
# (6700, astrID_wi    1113586
# variable      Siècle
# value
# Name: 6700, dtype: object)
# (6701, astrID_wi    1672269
# variable      Siècle
# value
# Name: 6701, dtype: object)
# (6702, astrID_wi    2643371
# variable      Siècle
# value
# Name: 6702, dtype: object)
# (6703, astrID_wi    2628410
# variable      Siècle
# value
# Name: 6703, dtype: object)
# (6704, astrID_wi    8088207
# variable      Siècle
# value
# Name: 6704, dtype: object)
# (6705, astrID_wi    8255450
# variable      Siècle
# value
# Name: 6705, dtype: object)
# (6706, astrID_wi    3696187
# variable      Siècle
# value
# Name: 6706, dtype: object)
# (6882, astrID_wi    4253488
# variable      Siècle
# value
# Name: 6882, dtype: object)
# (6883, astrID_wi    3517315
# variable      Siècle
# value
# Name: 6883, dtype: object)
# (6884, astrID_wi    3413674
# variable      Siècle
# value
# Name: 6884, dtype: object)
# (6885, astrID_wi    9875727
# variable      Siècle
# value
# Name: 6885, dtype: object)
# (6909, astrID_wi    1024841
# variable      Siècle
# value
# Name: 6909, dtype: object)
# (6936, astrID_wi    4517741
# variable      Siècle
# value
# Name: 6936, dtype: object)
# (7056, astrID_wi    3111851
# variable      Siècle
# value
# Name: 7056, dtype: object)
# (7131, astrID_wi    5903183
# variable      Siècle
# value
# Name: 7131, dtype: object)
# (7138, astrID_wi    2993157
# variable      Siècle
# value
# Name: 7138, dtype: object)
# (7140, astrID_wi    1694589
# variable      Siècle
# value
# Name: 7140, dtype: object)
# (7298, astrID_wi    7693816
# variable      Siècle
# value
# Name: 7298, dtype: object)
# (7366, astrID_wi    5038712
# variable      Siècle
# value
# Name: 7366, dtype: object)
# (7393, astrID_wi    7462440
# variable      Siècle
# value
# Name: 7393, dtype: object)
# (7400, astrID_wi    9732829
# variable      Siècle
# value
# Name: 7400, dtype: object)
# (7402, astrID_wi    2595806
# variable      Siècle
# value
# Name: 7402, dtype: object)
# (7403, astrID_wi    1758819
# variable      Siècle
# value
# Name: 7403, dtype: object)
# (7408, astrID_wi    5551065
# variable      Siècle
# value
# Name: 7408, dtype: object)
# (7409, astrID_wi    3028876
# variable      Siècle
# value
# Name: 7409, dtype: object)
# (7412, astrID_wi    7563809
# variable      Siècle
# value
# Name: 7412, dtype: object)
# (7416, astrID_wi    9393851
# variable      Siècle
# value
# Name: 7416, dtype: object)
# (7417, astrID_wi    2180720
# variable      Siècle
# value
# Name: 7417, dtype: object)
# (7421, astrID_wi    6337663
# variable      Siècle
# value
# Name: 7421, dtype: object)
# (7423, astrID_wi    2783726
# variable      Siècle
# value
# Name: 7423, dtype: object)
# (7424, astrID_wi    5199200
# variable      Siècle
# value
# Name: 7424, dtype: object)
# (7428, astrID_wi    8627779
# variable      Siècle
# value
# Name: 7428, dtype: object)
# (7433, astrID_wi    6104034
# variable      Siècle
# value
# Name: 7433, dtype: object)
# (7506, astrID_wi    2075864
# variable      Siècle
# value
# Name: 7506, dtype: object)
# (7508, astrID_wi    3136977
# variable      Siècle
# value
# Name: 7508, dtype: object)
# (7513, astrID_wi    8203610
# variable      Siècle
# value
# Name: 7513, dtype: object)
# (7521, astrID_wi    3158912
# variable      Siècle
# value
# Name: 7521, dtype: object)
# (7547, astrID_wi    7832643
# variable      Siècle
# value
# Name: 7547, dtype: object)
# (7560, astrID_wi    9219324
# variable      Siècle
# value
# Name: 7560, dtype: object)
# (7563, astrID_wi    9979948
# variable      Siècle
# value
# Name: 7563, dtype: object)
# (7564, astrID_wi    3315223
# variable      Siècle
# value
# Name: 7564, dtype: object)
# (7565, astrID_wi    1318958
# variable      Siècle
# value
# Name: 7565, dtype: object)
# (7566, astrID_wi    1442073
# variable      Siècle
# value
# Name: 7566, dtype: object)
# (7567, astrID_wi    8704421
# variable      Siècle
# value
# Name: 7567, dtype: object)
# (7568, astrID_wi    2706961
# variable      Siècle
# value
# Name: 7568, dtype: object)
# (7569, astrID_wi    5215062
# variable      Siècle
# value
# Name: 7569, dtype: object)
# (7579, astrID_wi    3755944
# variable      Siècle
# value
# Name: 7579, dtype: object)
# (7580, astrID_wi    3838496
# variable      Siècle
# value
# Name: 7580, dtype: object)
# (7581, astrID_wi    6640981
# variable      Siècle
# value
# Name: 7581, dtype: object)
# (7582, astrID_wi    2212311
# variable      Siècle
# value
# Name: 7582, dtype: object)
# (7583, astrID_wi    6928683
# variable      Siècle
# value
# Name: 7583, dtype: object)
# (7597, astrID_wi    2005697
# variable      Siècle
# value
# Name: 7597, dtype: object)
# (7598, astrID_wi    8823125
# variable      Siècle
# value
# Name: 7598, dtype: object)
# (7599, astrID_wi    1869352
# variable      Siècle
# value
# Name: 7599, dtype: object)
# (7600, astrID_wi    8962065
# variable      Siècle
# value
# Name: 7600, dtype: object)
# (7601, astrID_wi    6118357
# variable      Siècle
# value
# Name: 7601, dtype: object)
# (7602, astrID_wi    7606820
# variable      Siècle
# value
# Name: 7602, dtype: object)
# (7603, astrID_wi    7356175
# variable      Siècle
# value
# Name: 7603, dtype: object)
# (7604, astrID_wi    1648780
# variable      Siècle
# value
# Name: 7604, dtype: object)
# (7605, astrID_wi    8222114
# variable      Siècle
# value
# Name: 7605, dtype: object)
# (7606, astrID_wi    2566937
# variable      Siècle
# value
# Name: 7606, dtype: object)
# (7607, astrID_wi    9340937
# variable      Siècle
# value
# Name: 7607, dtype: object)
# (7608, astrID_wi    1404426
# variable      Siècle
# value
# Name: 7608, dtype: object)
# (7609, astrID_wi    5658061
# variable      Siècle
# value
# Name: 7609, dtype: object)
# (7610, astrID_wi    4575216
# variable      Siècle
# value
# Name: 7610, dtype: object)
# (7611, astrID_wi    4904667
# variable      Siècle
# value
# Name: 7611, dtype: object)
# (7612, astrID_wi    5298397
# variable      Siècle
# value
# Name: 7612, dtype: object)
# (7613, astrID_wi    2009846
# variable      Siècle
# value
# Name: 7613, dtype: object)
# (7614, astrID_wi    3153837
# variable      Siècle
# value
# Name: 7614, dtype: object)
# (7615, astrID_wi    8347698
# variable      Siècle
# value
# Name: 7615, dtype: object)
# (7616, astrID_wi    6039449
# variable      Siècle
# value
# Name: 7616, dtype: object)
# (7617, astrID_wi    1878364
# variable      Siècle
# value
# Name: 7617, dtype: object)
# (7618, astrID_wi    9416955
# variable      Siècle
# value
# Name: 7618, dtype: object)
# (7624, astrID_wi    5890830
# variable      Siècle
# value
# Name: 7624, dtype: object)
# (7625, astrID_wi    2670429
# variable      Siècle
# value
# Name: 7625, dtype: object)
# (7633, astrID_wi    4284387
# variable      Siècle
# value
# Name: 7633, dtype: object)
# (7634, astrID_wi    1486275
# variable      Siècle
# value
# Name: 7634, dtype: object)
# (7636, astrID_wi    8186777
# variable      Siècle
# value
# Name: 7636, dtype: object)
# (7703, astrID_wi    8696043
# variable      Siècle
# value
# Name: 7703, dtype: object)
# (7881, astrID_wi    8092582
# variable      Siècle
# value
# Name: 7881, dtype: object)
# (8032, astrID_wi    5655539
# variable      Siècle
# value
# Name: 8032, dtype: object)
# (8037, astrID_wi    5512449
# variable      Siècle
# value
# Name: 8037, dtype: object)
# (8068, astrID_wi    3926754
# variable      Siècle
# value
# Name: 8068, dtype: object)
# (8069, astrID_wi    8020751
# variable      Siècle
# value
# Name: 8069, dtype: object)
# (8070, astrID_wi    9690334
# variable      Siècle
# value
# Name: 8070, dtype: object)
# (8071, astrID_wi    5246664
# variable      Siècle
# value
# Name: 8071, dtype: object)
# (8072, astrID_wi    4940209
# variable      Siècle
# value
# Name: 8072, dtype: object)
# (8073, astrID_wi    5003576
# variable      Siècle
# value
# Name: 8073, dtype: object)
# (8074, astrID_wi    6519388
# variable      Siècle
# value
# Name: 8074, dtype: object)
# (8075, astrID_wi    1555295
# variable      Siècle
# value
# Name: 8075, dtype: object)
# (8076, astrID_wi    2700849
# variable      Siècle
# value
# Name: 8076, dtype: object)
# (8077, astrID_wi    7153800
# variable      Siècle
# value
# Name: 8077, dtype: object)
# (8161, astrID_wi    3075352
# variable      Siècle
# value
# Name: 8161, dtype: object)
# (8172, astrID_wi    7565752
# variable      Siècle
# value
# Name: 8172, dtype: object)
# (8175, astrID_wi    9065732
# variable      Siècle
# value
# Name: 8175, dtype: object)
# (8191, astrID_wi    7985736
# variable      Siècle
# value
# Name: 8191, dtype: object)
# (8192, astrID_wi    8951260
# variable      Siècle
# value
# Name: 8192, dtype: object)
# (8195, astrID_wi    3207335
# variable      Siècle
# value
# Name: 8195, dtype: object)
# (8202, astrID_wi    8951260
# variable      Siècle
# value
# Name: 8202, dtype: object)
# (8376, astrID_wi    8390642
# variable      Siècle
# value
# Name: 8376, dtype: object)
# (8460, astrID_wi    3785116
# variable      Siècle
# value
# Name: 8460, dtype: object)
# (8577, astrID_wi    7114629
# variable      Siècle
# value
# Name: 8577, dtype: object)
# (8578, astrID_wi    2808450
# variable      Siècle
# value
# Name: 8578, dtype: object)

# %%
result = g.query(
        """SELECT * WHERE {
            ?1s ?2p ?3o .
                }""")

pd.DataFrame(result.bindings).head()
# Out:
#                               1s  \
# 0  http://example.org/id/1202805
# 1  http://example.org/id/7439544
# 2    http://example.org/id/10384
# 3  http://example.org/id/3283681
# 4  http://example.org/id/5490346
#
#                                                 2p  \
# 0           http://example.org/vocab/pinakesFolios
# 1               http://example.org/vocab/pinakesID
# 2            http://example.org/vocab/pinakesLabel
# 3  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 4  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
#
#                                             3o
# 0                                    096v-104v
# 1                                  13115_49479
# 2                     fonds principal III C 16
# 3  http://www.w3.org/2004/02/skos/core#Concept
# 4  http://www.w3.org/2004/02/skos/core#Concept

# %% [markdown]
# ### Witness to Text

# %%
sql = """
SELECT DISTINCT astrID_wi, astrID_wo
 FROM `17.3.9_pinAstr_all`
 """
with connection.cursor() as cursor:
    cursor.execute(sql)
    names = [ x[0] for x in cursor.description]
    result = cursor.fetchall()
df = pd.DataFrame(result, columns = names)

df.head()
# Out:
#   astrID_wi astrID_wo
# 0   4512229    963140
# 1   4739938    698551
# 2   9876248    709263
# 3   6792546    473477
# 4   3068424    697381

# %%
# astrID_wo, astrID_wi from `17.3.9_pinAstr_all`

resources.append('astrID_wo')

verbs['http://example.org/vocab/witnessOf'] = list()
verbs['http://example.org/vocab/witnessOf'].append('astrID_wo')

resourceSyntax['http://example.org/id/'].append('astrID_wo')

# %%
primaryKey = 'astrID_wi'

g = convertToRDF(g,df,primaryKey)

# %%
result = g.query(
        """SELECT * WHERE {
            ?1s ?2p ?3o .
                }""")

pd.DataFrame(result.bindings).head()
# Out:
#                               1s  \
# 0  http://example.org/id/1202805
# 1  http://example.org/id/7439544
# 2    http://example.org/id/10384
# 3  http://example.org/id/3283681
# 4  http://example.org/id/5490346
#
#                                                 2p  \
# 0           http://example.org/vocab/pinakesFolios
# 1               http://example.org/vocab/pinakesID
# 2            http://example.org/vocab/pinakesLabel
# 3  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 4  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
#
#                                             3o
# 0                                    096v-104v
# 1                                  13115_49479
# 2                     fonds principal III C 16
# 3  http://www.w3.org/2004/02/skos/core#Concept
# 4  http://www.w3.org/2004/02/skos/core#Concept

# %%
# REVERSE
# astrID_wo, astrID_wi from `17.3.9_pinAstr_all`

verbs['http://example.org/vocab/hasWitness'] = list()
verbs['http://example.org/vocab/hasWitness'].append('astrID_wi')

# %%
primaryKey = 'astrID_wo'

g = convertToRDF(g,df,primaryKey)

# %%
result = g.query(
        """SELECT * WHERE {
            ?1s ?2p ?3o .
                }""")

pd.DataFrame(result.bindings).head()
# Out:
#                               1s  \
# 0  http://example.org/id/1202805
# 1  http://example.org/id/7439544
# 2    http://example.org/id/10384
# 3   http://example.org/id/840877
# 4  http://example.org/id/3283681
#
#                                                 2p  \
# 0           http://example.org/vocab/pinakesFolios
# 1               http://example.org/vocab/pinakesID
# 2            http://example.org/vocab/pinakesLabel
# 3  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 4  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
#
#                                             3o
# 0                                    096v-104v
# 1                                  13115_49479
# 2                     fonds principal III C 16
# 3  http://www.w3.org/2004/02/skos/core#Concept
# 4  http://www.w3.org/2004/02/skos/core#Concept

# %% [markdown]
# ## Texts and Authors
# ### astrID_wo to Pinakes Info, astrID_au

# %%
sql = """
SELECT DISTINCT astrID_wo, workID, Oeuvre, astrID_au
 FROM `17.3.9_pinAstr_all`
 """
with connection.cursor() as cursor:
    cursor.execute(sql)
    names = [ x[0] for x in cursor.description]
    result = cursor.fetchall()
df = pd.DataFrame(result, columns = names)

df.head()
# Out:
#   astrID_wo workID                                             Oeuvre  \
# 0    963140   6769                       Hermippus Siue De Astrologia
# 1    698551   1484                   Commentaria in Ptolemaei canones
# 2    709263    913                             Canon urbium insignium
# 3    473477    969  Canones Prompti (manuale : Ed. Heiberg Ii, P. ...
# 4    697381  12764  Syntaxis mathematica (Almageste) (Lib. I-XIII ...
#
#   astrID_au
# 0      8487
# 1      3114
# 2      8572
# 3      8572
# 4      8572

# %%
# astrID_wo, workID, Oeuvre, astrID_au from `17.3.9_pinAstr_all`

literals.append('workID')
literals.append('Oeuvre')

resources.append('astrID_au')

verbs['http://example.org/vocab/pinakesID'].append('workID')

verbs['http://example.org/vocab/pinakesLabel'].append('Oeuvre')

verbs['http://purl.org/dc/elements/1.1/creator'] = list()
verbs['http://purl.org/dc/elements/1.1/creator'].append('astrID_au')

resourceSyntax['http://example.org/id/'].append('astrID_au')

# %%
primaryKey = 'astrID_wo'

g = convertToRDF(g,df,primaryKey)

# %%
result = g.query(
        """SELECT * WHERE {
            ?1s ?2p ?3o .
                }""")

pd.DataFrame(result.bindings).head()
# Out:
#                               1s  \
# 0  http://example.org/id/1202805
# 1  http://example.org/id/7439544
# 2    http://example.org/id/10384
# 3   http://example.org/id/840877
# 4  http://example.org/id/3283681
#
#                                                 2p  \
# 0           http://example.org/vocab/pinakesFolios
# 1               http://example.org/vocab/pinakesID
# 2            http://example.org/vocab/pinakesLabel
# 3  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 4  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
#
#                                             3o
# 0                                    096v-104v
# 1                                  13115_49479
# 2                     fonds principal III C 16
# 3  http://www.w3.org/2004/02/skos/core#Concept
# 4  http://www.w3.org/2004/02/skos/core#Concept

# %% [markdown]
# ### Author to Pinakes Info

# %%
sql = """
SELECT DISTINCT astrID_au, AuthorID, Auteur
 FROM `17.3.9_pinAstr_all`
 """
with connection.cursor() as cursor:
    cursor.execute(sql)
    names = [ x[0] for x in cursor.description]
    result = cursor.fetchall()
df = pd.DataFrame(result, columns = names)

df.head()
# Out:
#   astrID_au AuthorID                Auteur
# 0      8487      635     Iohannes Catrones
# 1      3114     2723    Theon Alexandrinus
# 2      8572     2416   Ptolemaeus Claudius
# 3      6152      857              Damianus
# 4      1282     2785  Triclinius Demetrius

# %%
# astrID_au, AuthorID, Auteur from `17.3.9_pinAstr_all`

literals.append('AuthorID')
literals.append('Auteur')

verbs['http://example.org/vocab/pinakesID'].append('AuthorID')

verbs['http://example.org/vocab/pinakesLabel'].append('Auteur')

# %%
primaryKey = 'astrID_au'

g = convertToRDF(g,df,primaryKey)

# %%
result = g.query(
        """SELECT * WHERE {
            ?1s <http://example.org/vocab/pinakesLabel> ?3o .
                }""")

pd.DataFrame(result.bindings).head()
# Out:
#                              1s                                    3o
# 0  http://example.org/id/914324                           Onomasticon
# 1  http://example.org/id/701770      Scholia In Aristotelis Analytica
# 2    http://example.org/id/1221                      Hierocles quidam
# 3   http://example.org/id/10384              fonds principal III C 16
# 4  http://example.org/id/717345  Introductio in Tetrabiblum Ptolemaei

# %% [markdown]
# ## Some Queries

# %% [markdown]
# Finding all texts attributed to Euclid in the Pinakes database.

# %%
result = g.query(
        """SELECT * WHERE {
            # ?au <http://example.org/vocab/pinakesLabel> 'Euclides' .
            # ?wo <http://purl.org/dc/elements/1.1/creator> ?au .
            # ?wo <http://example.org/vocab/pinakesLabel> ?la .
                }""")

pd.DataFrame(result.bindings)
# Out:
#                            au                     la  \
# 0  http://example.org/id/5215             Phaenomena
# 1  http://example.org/id/5215     Catoptrica (spur.)
# 2  http://example.org/id/5215  Introductio harmonica
# 3  http://example.org/id/5215               Elementa
# 4  http://example.org/id/5215              Epigramma
# 5  http://example.org/id/5215         Sectio canonis
# 6  http://example.org/id/5215                  Opera
# 7  http://example.org/id/5215                   Data
# 8  http://example.org/id/5215                 Optica
#
#                              wo
# 0  http://example.org/id/721862
# 1  http://example.org/id/544877
# 2  http://example.org/id/360545
# 3  http://example.org/id/777790
# 4  http://example.org/id/422006
# 5  http://example.org/id/425216
# 6  http://example.org/id/132659
# 7  http://example.org/id/613097
# 8  http://example.org/id/154837

# %% [markdown]
# Count how many texts by a certain author (below Euclid) appears in each manuscript.

# %%
pinakes_authorName = 'Euclides'
# For this query it is necessary to know how the author is named
# in the Pinakes database.

result = g.query(
        """
        PREFIX ex: <http://example.org/vocab/>
        PREFIX dc: <http://purl.org/dc/elements/1.1/>
        PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
        SELECT ?ms ?shelfmark (COUNT(*) AS ?c) WHERE {
            # ?au ex:pinakesLabel '%s' .
            # ?wo dc:creator ?au ;
                ex:pinakesLabel ?l_wo ;
                ex:hasWitness/ex:inMS ?ms .
            # ?ms ex:pinakesLabel ?l_ms ;
                ex:locatedIn/skos:prefLabel ?l_inst .
            BIND(CONCAT(?l_inst, " ", ?l_ms) AS ?shelfmark)
                }
                GROUP BY ?ms
                ORDER BY DESC(?c)
                """ % pinakes_authorName)

pd.DataFrame(result.bindings)
# Out:
#      c                           ms  \
# 0    6  http://example.org/id/60423
# 1    5  http://example.org/id/54144
# 2    5  http://example.org/id/51986
# 3    5  http://example.org/id/48620
# 4    5  http://example.org/id/27520
# 5    5  http://example.org/id/53234
# 6    5  http://example.org/id/38870
# 7    5  http://example.org/id/38820
# 8    4  http://example.org/id/51392
# 9    4  http://example.org/id/97374
# 10   4  http://example.org/id/21139
# 11   4  http://example.org/id/84028
# 12   4  http://example.org/id/10018
# 13   4  http://example.org/id/17320
# 14   4  http://example.org/id/24333
# 15   3  http://example.org/id/92714
# 16   3  http://example.org/id/89276
# 17   3  http://example.org/id/92956
# 18   3  http://example.org/id/38782
# 19   3  http://example.org/id/13457
# 20   3  http://example.org/id/53448
# 21   3  http://example.org/id/56874
# 22   3  http://example.org/id/14930
# 23   2  http://example.org/id/64425
# 24   2  http://example.org/id/63530
# 25   2  http://example.org/id/40748
# 26   2  http://example.org/id/91291
# 27   2  http://example.org/id/82030
# 28   2  http://example.org/id/58660
# 29   2  http://example.org/id/69241
# ..  ..                          ...
# 80   1  http://example.org/id/62037
# 81   1  http://example.org/id/58834
# 82   1  http://example.org/id/27555
# 83   1  http://example.org/id/48404
# 84   1  http://example.org/id/49580
# 85   1  http://example.org/id/17899
# 86   1  http://example.org/id/51439
# 87   1  http://example.org/id/32360
# 88   1  http://example.org/id/91842
# 89   1  http://example.org/id/45543
# 90   1  http://example.org/id/92004
# 91   1  http://example.org/id/92917
# 92   1  http://example.org/id/89978
# 93   1  http://example.org/id/91649
# 94   1  http://example.org/id/10017
# 95   1  http://example.org/id/26661
# 96   1  http://example.org/id/74757
# 97   1  http://example.org/id/58936
# 98   1  http://example.org/id/53339
# 99   1  http://example.org/id/81231
# 100  1  http://example.org/id/20467
# 101  1  http://example.org/id/34813
# 102  1  http://example.org/id/84606
# 103  1  http://example.org/id/63658
# 104  1  http://example.org/id/15997
# 105  1  http://example.org/id/43441
# 106  1  http://example.org/id/54405
# 107  1  http://example.org/id/41582
# 108  1  http://example.org/id/33198
# 109  1  http://example.org/id/29934
#
#                                              shelfmark
# 0    Staatsbibliothek zu Berlin (Preussischer Kultu...
# 1    Biblioteca comunale degli Intronati fonds prin...
# 2      Bibliothèque nationale de France (BNF) gr. 2347
# 3      Bibliothèque nationale de France (BNF) gr. 2342
# 4          Biblioteca Apostolica Vaticana Vat. gr. 192
# 5    Biblioteca Ambrosiana fonds principal A 101 su...
# 6              Bibliotheek der Rijksuniversiteit BPG 7
# 7                           Biblioteca Angelica gr. 95
# 8          Biblioteca Apostolica Vaticana Vat. gr. 204
# 9    Biblioteca Nazionale Marciana gr. Z. 302 (coll...
# 10   Biblioteca Nazionale Marciana gr. Z. 301 (coll...
# 11            Biblioteca Apostolica Vaticana Ross. 978
# 12       Biblioteca Universitaria fonds principal 2048
# 13         Biblioteca Apostolica Vaticana Vat. gr. 191
# 14     Bibliothèque nationale de France (BNF) gr. 2350
# 15      Herzog August Bibliothek Gud. gr. Gud. gr. 036
# 16         Biblioteca Apostolica Vaticana Vat. gr. 202
# 17   Real Biblioteca fonds principal ?. II. 13 (And...
# 18   Bibliothèque nationale de France (BNF) suppl. ...
# 19   Bibliothèque nationale de France (BNF) suppl. ...
# 20   University Library Fonds ancien Gg. II. 33 (1463)
# 21   Biblioteca Nazionale Marciana gr. Z. 303 (coll...
# 22     Bibliothèque nationale de France (BNF) gr. 2366
# 23   Biblioteca Ambrosiana fonds principal Q 105 su...
# 24     Bibliothèque nationale de France (BNF) gr. 2460
# 25     Bibliothèque nationale de France (BNF) gr. 2448
# 26   Biblioteca nacional de España fonds principal ...
# 27   Biblioteca Ambrosiana fonds principal A 071 in...
# 28   Biblioteca Nazionale Marciana gr. Z. 322 (coll...
# 29          Biblioteca Apostolica Vaticana Reg. gr. 94
# ..                                                 ...
# 80      Bibliotheek der Rijksuniversiteit Scal. gr. 48
# 81       Biblioteca Apostolica Vaticana Ottob. gr. 192
# 82    Bibliotheek der Rijksuniversiteit Voss. Misc. 18
# 83             Lincoln College fonds principal gr. 033
# 84         Biblioteca Apostolica Vaticana Vat. gr. 221
# 85     Bibliothèque nationale de France (BNF) gr. 2348
# 86                 Gumnasion fonds principal 0382 (83)
# 87   Bibliothèque nationale de France (BNF) suppl. ...
# 88   Real Biblioteca fonds principal ?. II. 05 (And...
# 89                 Det Kongelige Bibliotek GKS 1871 4°
# 90   Biblioteca Ambrosiana fonds principal N 289 su...
# 91     Bibliothèque nationale de France (BNF) gr. 2349
# 92         Bodleian Library Auct. F. 3. 18 (Misc. 092)
# 93   Staatsbibliothek zu Berlin (Preussischer Kultu...
# 94        Biblioteca Apostolica Vaticana Vat. gr. 1346
# 95                        Bodleian Library Langbaine 3
# 96   Real Biblioteca fonds principal ?. IV. 01 (And...
# 97     Bibliothèque nationale de France (BNF) gr. 2008
# 98        Biblioteca Apostolica Vaticana Vat. gr. 1379
# 99                         Bodleian Library Barocci 76
# 100  Thirlestaine House, coll. Phillipps fonds prin...
# 101  University Library Fonds ancien Dd. III. 86 (173)
# 102       Biblioteca Apostolica Vaticana Barb. gr. 265
# 103    Bibliothèque nationale de France (BNF) gr. 2475
# 104    Bibliothèque nationale de France (BNF) gr. 1670
# 105        Biblioteca Apostolica Vaticana Pal. gr. 137
# 106     Biblioteca Medicea Laurenziana Acq. e Doni 168
# 107  Biblioteca Ambrosiana fonds principal B 038 su...
# 108  Real Biblioteca fonds principal ?. I. 12 (Andr...
# 109  Bibliothèque nationale de France (BNF) suppl. ...
#
# [110 rows x 3 columns]

# %%
pinakes_authorName = 'Euclides'

result = g.query(
        """
        PREFIX ex: <http://example.org/vocab/>
        PREFIX dc: <http://purl.org/dc/elements/1.1/>
        PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
        SELECT ?au ?ms ?shelfmark ?c WHERE {
        {
        SELECT ?au ?ms ?shelfmark (COUNT(*) AS ?c)  WHERE {
            # ?au ex:pinakesLabel 'Euclides' .
            # ?wo dc:creator ?au ;
                ex:pinakesLabel ?l_wo ;
                ex:hasWitness/ex:inMS ?ms .
            # ?ms ex:pinakesLabel ?l_ms ;
                ex:locatedIn/skos:prefLabel ?l_inst .
            BIND(CONCAT(?l_inst, " ", ?l_ms) AS ?shelfmark)
            BIND('Euclides' AS ?au)
                }
                GROUP BY ?ms
                ORDER BY DESC(?c)
                LIMIT 1
        } UNION {
        SELECT ?au ?ms ?shelfmark (COUNT(*) AS ?c)  WHERE {
            # ?au ex:pinakesLabel 'Theodosius Tripolita' .
            # ?wo dc:creator ?au ;
                ex:pinakesLabel ?l_wo ;
                ex:hasWitness/ex:inMS ?ms .
            # ?ms ex:pinakesLabel ?l_ms ;
                ex:locatedIn/skos:prefLabel ?l_inst .
            BIND(CONCAT(?l_inst, " ", ?l_ms) AS ?shelfmark)
            BIND('Theodosius Tripolita' AS ?au)
                }
                GROUP BY ?ms
                ORDER BY DESC(?c)
                LIMIT 1
        } UNION {
        SELECT ?au ?ms ?shelfmark (COUNT(*) AS ?c)  WHERE {
            # ?au ex:pinakesLabel 'Autolycus astronomus' .
            # ?wo dc:creator ?au ;
                ex:pinakesLabel ?l_wo ;
                ex:hasWitness/ex:inMS ?ms .
            # ?ms ex:pinakesLabel ?l_ms ;
                ex:locatedIn/skos:prefLabel ?l_inst .
            BIND(CONCAT(?l_inst, " ", ?l_ms) AS ?shelfmark)
            BIND('Autolycus astronomus' AS ?au)
                }
                GROUP BY ?ms
                ORDER BY DESC(?c)
                LIMIT 1
        } UNION {
        SELECT ?au ?ms ?shelfmark (COUNT(*) AS ?c)  WHERE {
            # ?au ex:pinakesLabel 'Ptolemaeus Claudius' .
            # ?wo dc:creator ?au ;
                ex:pinakesLabel ?l_wo ;
                ex:hasWitness/ex:inMS ?ms .
            # ?ms ex:pinakesLabel ?l_ms ;
                ex:locatedIn/skos:prefLabel ?l_inst .
            BIND(CONCAT(?l_inst, " ", ?l_ms) AS ?shelfmark)
            BIND('Ptolemaeus Claudius' AS ?au)
                }
                GROUP BY ?ms
                ORDER BY DESC(?c)
                LIMIT 1
        }
        }
                """ )

pd.DataFrame(result.bindings)
# Out:
#                      au  c                           ms  \
# 0              Euclides  6  http://example.org/id/60423
# 1  Theodosius Tripolita  4  http://example.org/id/40159
# 2  Autolycus astronomus  3  http://example.org/id/54144
# 3   Ptolemaeus Claudius  6  http://example.org/id/92514
#
#                                            shelfmark
# 0  Staatsbibliothek zu Berlin (Preussischer Kultu...
# 1  Bibliothèque nationale de France (BNF) suppl. ...
# 2  Biblioteca comunale degli Intronati fonds prin...
# 3                       Bodleian Library Cromwell 12

# %% [markdown]
# Find all manuscripts containing at least one text from any given grouping of texts. The case below is the 11 Little Astronomy texts. `pinID`s provided to check (`pinakes.irht.cnrs.fr/notices/cote/?pinID/` -- replace `?pinID` with the given number).

# %%
pinakes_works = list()
pinakes_works = ('154837','544877','613097','721862','791205','926906','314341','966647','708053','399200','559345','150679')
# Above are the 11 LA works (technically 12 because of Theon's recension of Euclid's Optics)

query = """
PREFIX ex: <http://example.org/vocab/>
        PREFIX exi: <http://example.org/id/>
        PREFIX dc: <http://purl.org/dc/terms/>
        PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
        
        SELECT ?ms (COUNT(*) AS ?c) ?pinID WHERE {
"""

for work in pinakes_works:
    if work == pinakes_works[0]:
        query = query + """
            {
                SELECT ?ms ?wit ?pinID WHERE {
                    # ?wit ex:inMS ?ms ;
                         ex:witnessOf exi:%s ;
                         ex:inMS/ex:pinakesID ?pinID . 
                }
            }
        """ % work
    else:
        query = query + """ UNION
            {
                SELECT ?ms ?wit ?pinID WHERE {
                    # ?wit ex:inMS ?ms ;
                         ex:witnessOf exi:%s ;
                         ex:inMS/ex:pinakesID ?pinID . 
                }
            }
        """ % work
        
query = query + """
        }
        GROUP BY ?ms
        ORDER BY DESC(?c)
        """




result = g.query(query)

pd.DataFrame(result.bindings)
# Out:
#      c                           ms  pinID
# 0   11  http://example.org/id/48620  51974
# 1   11  http://example.org/id/84028  66447
# 2   11  http://example.org/id/17320  66822
# 3   11  http://example.org/id/53234  42210
# 4    9  http://example.org/id/51392  66835
# 5    8  http://example.org/id/14930  51998
# 6    8  http://example.org/id/89276  66833
# 7    7  http://example.org/id/19133  66834
# 8    7  http://example.org/id/54144  58281
# 9    6  http://example.org/id/27520  66823
# 10   6  http://example.org/id/40159  52784
# 11   5  http://example.org/id/44122  64813
# 12   5  http://example.org/id/94675  42502
# 13   5  http://example.org/id/51986  51979
# 14   5  http://example.org/id/83963  42912
# 15   4  http://example.org/id/88148  15513
# 16   4  http://example.org/id/97374  69773
# 17   4  http://example.org/id/40748  52080
# 18   4  http://example.org/id/24333  51982
# 19   4  http://example.org/id/38782  52783
# 20   4  http://example.org/id/38820  56001
# 21   4  http://example.org/id/60423   9453
# 22   4  http://example.org/id/38870  37630
# 23   4  http://example.org/id/21139  69772
# 24   3  http://example.org/id/18490  52022
# 25   3  http://example.org/id/13128  72752
# 26   3  http://example.org/id/15322  16945
# 27   3  http://example.org/id/92714  72080
# 28   2  http://example.org/id/64425  43174
# 29   2  http://example.org/id/32782  48426
# 30   2  http://example.org/id/10018   9713
# 31   2  http://example.org/id/83404  53193
# 32   2  http://example.org/id/13457  52965
# 33   2  http://example.org/id/53448  12191
# 34   2  http://example.org/id/81917  51997
# 35   2  http://example.org/id/56874  69774
# 36   1  http://example.org/id/48614  48427
# 37   1  http://example.org/id/62037  37993
# 38   1  http://example.org/id/27555  38205
# 39   1  http://example.org/id/17899  51980
# 40   1  http://example.org/id/70873  42607
# 41   1  http://example.org/id/65283  12000
# 42   1  http://example.org/id/25304  52099
# 43   1  http://example.org/id/51467  43510
# 44   1  http://example.org/id/92917  51981
# 45   1  http://example.org/id/27261  16182
# 46   1  http://example.org/id/35515  48432
# 47   1  http://example.org/id/52320  66547
# 48   1  http://example.org/id/92956  14610
# 49   1  http://example.org/id/51239  66821
# 50   1  http://example.org/id/54405  15716
# 51   1  http://example.org/id/45178  51608

# %% [markdown]
# Count how many texts appear in each manuscript. `pinID`s provided to check (`pinakes.irht.cnrs.fr/notices/cote/?pinID/` -- replace `?pinID` with the given number).

# %%
result = g.query(
        """
        PREFIX ex: <http://example.org/vocab/>
        PREFIX dc: <http://purl.org/dc/elements/1.1/>
        PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
        SELECT ?ms ?pinID ?shelfmark (COUNT(*) AS ?c) WHERE {
            # ?wo dc:creator ?au ;
                ex:pinakesLabel ?l_wo ;
                ex:hasWitness/ex:inMS ?ms .
            # ?ms ex:pinakesLabel ?l_ms ;
                ex:locatedIn/skos:prefLabel ?l_inst ;
                ex:pinakesID ?pinID .
            BIND(CONCAT(?l_inst, " ", ?l_ms) AS ?shelfmark)
                }
                GROUP BY ?ms
                ORDER BY DESC(?c)
                """)

pd.DataFrame(result.bindings)
# Out:
#        c                           ms  pinID  \
# 0    138  http://example.org/id/63517  14971
# 1     67  http://example.org/id/81231  47363
# 2     57  http://example.org/id/37794  52051
# 3     55  http://example.org/id/58834  65435
# 4     54  http://example.org/id/57004  68511
# 5     47  http://example.org/id/33726  52013
# 6     45  http://example.org/id/40321  68527
# 7     38  http://example.org/id/82731  52183
# 8     37  http://example.org/id/52320  66547
# 9     34  http://example.org/id/17320  66822
# 10    32  http://example.org/id/16561  48178
# 11    30  http://example.org/id/47908  13440
# 12    29  http://example.org/id/80751  44548
# 13    25  http://example.org/id/94675  42502
# 14    24  http://example.org/id/27555  38205
# 15    24  http://example.org/id/92514  47802
# 16    24  http://example.org/id/68432  64617
# 17    23  http://example.org/id/47576  44549
# 18    23  http://example.org/id/70307  69805
# 19    21  http://example.org/id/41482  69794
# 20    20  http://example.org/id/94009  16215
# 21    20  http://example.org/id/40382  69275
# 22    19  http://example.org/id/80433  43201
# 23    19  http://example.org/id/53234  42210
# 24    19  http://example.org/id/48620  51974
# 25    19  http://example.org/id/33741  50162
# 26    18  http://example.org/id/44122  64813
# 27    18  http://example.org/id/98003  66544
# 28    18  http://example.org/id/85473  47412
# 29    17  http://example.org/id/58521  67690
# ..   ...                          ...    ...
# 327    1  http://example.org/id/83313  52028
# 328    1  http://example.org/id/56958  48608
# 329    1  http://example.org/id/71389   9630
# 330    1  http://example.org/id/89268  15719
# 331    1  http://example.org/id/86332  13724
# 332    1  http://example.org/id/10384  46292
# 333    1  http://example.org/id/78728  46291
# 334    1  http://example.org/id/83306  46952
# 335    1  http://example.org/id/37146  12570
# 336    1  http://example.org/id/51782  53644
# 337    1  http://example.org/id/25593  52023
# 338    1  http://example.org/id/28543  48196
# 339    1  http://example.org/id/20808   6574
# 340    1  http://example.org/id/53632  69782
# 341    1  http://example.org/id/86643  68206
# 342    1  http://example.org/id/98753  52027
# 343    1  http://example.org/id/57792   8996
# 344    1  http://example.org/id/13760  16947
# 345    1  http://example.org/id/65855  46290
# 346    1  http://example.org/id/86430  64303
# 347    1  http://example.org/id/41625  37976
# 348    1  http://example.org/id/53665  52000
# 349    1  http://example.org/id/56204  56060
# 350    1  http://example.org/id/75856  64468
# 351    1  http://example.org/id/17546  68354
# 352    1  http://example.org/id/83896  45091
# 353    1  http://example.org/id/37642  53639
# 354    1  http://example.org/id/37199  42626
# 355    1  http://example.org/id/59873  17163
# 356    1  http://example.org/id/38962  52908
#
#                                              shelfmark
# 0    Real Biblioteca fonds principal ?. I. 13 (Andr...
# 1                          Bodleian Library Barocci 76
# 2      Bibliothèque nationale de France (BNF) gr. 2419
# 3        Biblioteca Apostolica Vaticana Ottob. gr. 192
# 4         Biblioteca Apostolica Vaticana Vat. gr. 1882
# 5      Bibliothèque nationale de France (BNF) gr. 2381
# 6         Biblioteca Apostolica Vaticana Vat. gr. 1898
# 7      Bibliothèque nationale de France (BNF) gr. 2551
# 8           Biblioteca Apostolica Vaticana Urb. gr. 80
# 9          Biblioteca Apostolica Vaticana Vat. gr. 191
# 10                    Bodleian Library Holkham gr. 110
# 11                Monê Kosinitsês fonds principal S.N.
# 12         Bayerische Staatsbibliothek Cod. graec. 104
# 13   Biblioteca Ambrosiana fonds principal C 263 in...
# 14    Bibliotheek der Rijksuniversiteit Voss. Misc. 18
# 15                        Bodleian Library Cromwell 12
# 16         Biblioteca Apostolica Vaticana Barb. gr. 69
# 17         Bayerische Staatsbibliothek Cod. graec. 105
# 18   Biblioteca Nazionale Marciana gr. Z. 334 (coll...
# 19   Biblioteca Nazionale Marciana gr. Z. 323 (coll...
# 20         Biblioteca Medicea Laurenziana Plut. 28. 34
# 21        Biblioteca Apostolica Vaticana Vat. gr. 2644
# 22   Biblioteca Ambrosiana fonds principal R 117 su...
# 23   Biblioteca Ambrosiana fonds principal A 101 su...
# 24     Bibliothèque nationale de France (BNF) gr. 2342
# 25      Bibliothèque nationale de France (BNF) gr. 583
# 26        Biblioteca Apostolica Vaticana Barb. gr. 267
# 27          Biblioteca Apostolica Vaticana Urb. gr. 77
# 28                        Bodleian Library Barocci 125
# 29        Biblioteca Apostolica Vaticana Vat. gr. 1059
# ..                                                 ...
# 327    Bibliothèque nationale de France (BNF) gr. 2396
# 328           Christ Church College fonds principal 86
# 329        Bibliothèque municipale fonds principal 480
# 330   Biblioteca Medicea Laurenziana Acq. e Doni 170.2
# 331  National Library of Scotland fonds principal A...
# 332      Biblioteca Nazionale fonds principal III C 16
# 333      Biblioteca Nazionale fonds principal III C 15
# 334                 Bodleian Library Arch. Seld. B. 44
# 335  Thirlestaine House, coll. Phillipps fonds prin...
# 336  Bibliothèque nationale de France (BNF) suppl. ...
# 337    Bibliothèque nationale de France (BNF) gr. 2391
# 338                       Bodleian Library Langbaine 4
# 339  Ethnikê Bibliothêkê tês Hellados (EBE) Metochi...
# 340  Biblioteca Nazionale Marciana gr. Z. 311 (coll...
# 341       Biblioteca Apostolica Vaticana Vat. gr. 1575
# 342    Bibliothèque nationale de France (BNF) gr. 2395
# 343  Biblioteca Lolliniana (del Seminario) fonds pr...
# 344  Biblioteca Nazionale Centrale Magl. Magliabecc...
# 345      Biblioteca Nazionale fonds principal III C 14
# 346       Universitätsbibliothek fonds principal Mb 06
# 347     Bibliotheek der Rijksuniversiteit Scal. gr. 15
# 348    Bibliothèque nationale de France (BNF) gr. 2368
# 349         Biblioteca Casanatense fonds principal 455
# 350                          UB fonds principal gr. 55
# 351       Biblioteca Apostolica Vaticana Vat. gr. 1725
# 352        Bayerische Staatsbibliothek Cod. graec. 641
# 353  Bibliothèque nationale de France (BNF) suppl. ...
# 354  Biblioteca Ambrosiana fonds principal D 336 in...
# 355      Bibliothêkê tês Koinotêtos fonds principal 28
# 356  Bibliothèque nationale de France (BNF) suppl. ...
#
# [357 rows x 4 columns]
